# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import etl.data_loader as dl
import eda.eda_engine as eda

# %%
data_loader = dl.DataLoader("data/dataset.csv")
data_df = data_loader.load_data()

# %%
eda_engine = eda.EDA_Engine(data_df)
eda_engine.overview()
eda_engine.granular_unique_categorical_values()
# Out:
# Dataset Shape: (1460, 22)
#
#
# Data Types:
# LotArea               int64
# GrLivArea             int64
# Street               object
# Alley                object
# LotType              object
# BldgType             object
# HouseStyle           object
# OverallQuality        int64
# OverallCondition      int64
# YearBuilt             int64
# Foundation           object
# TotalBsmtSF           int64
# CentralAir           object
# FullBath              int64
# HalfBath              int64
# GarageType           object
# GarageCars            int64
# GarageArea          float64
# YearSold              int64
# SaleType             object
# SaleCondition        object
# SalePrice             int64
# dtype: object
#
#
# First few rows:
#    LotArea  GrLivArea Street Alley  LotType BldgType HouseStyle  \
# 0     8910       1194   Pave   NaN   Corner     1Fam       1Fam
# 1     1526        630   Pave   NaN   Inside    Twnhs     SFoyer
# 2    14598       1933   Pave   NaN  CulDSac     1Fam     2Story
# 3     7200       1040   Pave   NaN   Inside   Duplex     1Story
# 4     5687       1716   Pave  Grvl   Inside   2fmCon     2Story
# 5     8100       1559   Pave  Pave   Inside     1Fam     1Story
# 6     9600       1644   Pave   NaN   Inside     1Fam     1Story
# 7     3182       1200   Pave  Pave   Inside   TwnhsE     2Story
# 8     6040       1152   Pave   NaN   Inside   Duplex     1Story
# 9    20544       2093   Pave   NaN  CulDSac     1Fam     2Story
#
#    OverallQuality  OverallCondition  YearBuilt  ... CentralAir  FullBath  \
# 0               6                 6       1959  ...          Y         1
# 1               4                 8       1970  ...          Y         1
# 2               6                 5       2007  ...          Y         2
# 3               4                 5       1949  ...          N         2
# 4               5                 6       1912  ...          N         2
# 5               5                 6       1948  ...          Y         1
# 6               6                 5       1953  ...          Y         1
# 7               7                 5       2004  ...          Y         2
# 8               4                 5       1955  ...          N         2
# 9               7                 6       1986  ...          Y         2
#
#   HalfBath  GarageType  GarageCars GarageArea  YearSold  SaleType  \
# 0        0     BuiltIn           2      539.0      2006        WD
# 1        0      Attchd           1      286.0      2009        WD
# 2        1     BuiltIn           3      668.0      2008        WD
# 3        0      Detchd           2      420.0      2009        WD
# 4        0         NaN           0        0.0      2008        WD
# 5        0      Detchd           2      812.0      2007       COD
# 6        0      Attchd           2      418.0      2009        WD
# 7        1      Detchd           2      480.0      2010        WD
# 8        0         NaN           0        0.0      2008        WD
# 9        1      Attchd           2      542.0      2008        WD
#
#    SaleCondition SalePrice
# 0         Normal    159500
# 1         Normal     86000
# 2         Normal    214000
# 3         Normal     90000
# 4         Normal    135900
# 5         Normal    153500
# 6         Normal    167000
# 7         Normal    151000
# 8        AdjLand     82000
# 9         Normal    215000
#
# [10 rows x 22 columns]
#
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   GrLivArea         1460 non-null   int64
#  2   Street            1460 non-null   object
#  3   Alley             91 non-null     object
#  4   LotType           1460 non-null   object
#  5   BldgType          1460 non-null   object
#  6   HouseStyle        1460 non-null   object
#  7   OverallQuality    1460 non-null   int64
#  8   OverallCondition  1460 non-null   int64
#  9   YearBuilt         1460 non-null   int64
#  10  Foundation        1460 non-null   object
#  11  TotalBsmtSF       1460 non-null   int64
#  12  CentralAir        1460 non-null   object
#  13  FullBath          1460 non-null   int64
#  14  HalfBath          1460 non-null   int64
#  15  GarageType        1379 non-null   object
#  16  GarageCars        1460 non-null   int64
#  17  GarageArea        1417 non-null   float64
#  18  YearSold          1460 non-null   int64
#  19  SaleType          1460 non-null   object
#  20  SaleCondition     1460 non-null   object
#  21  SalePrice         1460 non-null   int64
# dtypes: float64(1), int64(11), object(10)
# memory usage: 251.1+ KB
# None
#
#
# DataFrame columns:
# Index(['LotArea', 'GrLivArea', 'Street', 'Alley', 'LotType', 'BldgType',
#        'HouseStyle', 'OverallQuality', 'OverallCondition', 'YearBuilt',
#        'Foundation', 'TotalBsmtSF', 'CentralAir', 'FullBath', 'HalfBath',
#        'GarageType', 'GarageCars', 'GarageArea', 'YearSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')
#
#
# DataFrame index:
# RangeIndex(start=0, stop=1460, step=1)
#
#
# DataFrame nr. unique values:
# LotArea             1073
# GrLivArea            863
# Street                 2
# Alley                  2
# LotType                5
# BldgType               5
# HouseStyle             9
# OverallQuality        10
# OverallCondition       9
# YearBuilt            112
# Foundation             7
# TotalBsmtSF          721
# CentralAir             2
# FullBath               4
# HalfBath               3
# GarageType             6
# GarageCars             5
# GarageArea           435
# YearSold               5
# SaleType               9
# SaleCondition          7
# SalePrice            663
# dtype: int64
#
#
# DataFrame nr. missing values:
# LotArea                0
# GrLivArea              0
# Street                 0
# Alley               1369
# LotType                0
# BldgType               0
# HouseStyle             0
# OverallQuality         0
# OverallCondition       0
# YearBuilt              0
# Foundation             0
# TotalBsmtSF            0
# CentralAir             0
# FullBath               0
# HalfBath               0
# GarageType            81
# GarageCars             0
# GarageArea            43
# YearSold               0
# SaleType               0
# SaleCondition          0
# SalePrice              0
# dtype: int64
#
#
# DataFrame missing values percentage:
# LotArea              0.000000
# GrLivArea            0.000000
# Street               0.000000
# Alley               93.767123
# LotType              0.000000
# BldgType             0.000000
# HouseStyle           0.000000
# OverallQuality       0.000000
# OverallCondition     0.000000
# YearBuilt            0.000000
# Foundation           0.000000
# TotalBsmtSF          0.000000
# CentralAir           0.000000
# FullBath             0.000000
# HalfBath             0.000000
# GarageType           5.547945
# GarageCars           0.000000
# GarageArea           2.945205
# YearSold             0.000000
# SaleType             0.000000
# SaleCondition        0.000000
# SalePrice            0.000000
# dtype: float64

# %%
eda_engine.granular_unique_categorical_values()
# Out:
# Granular unique categorical values:
#
# 2 Column: Street --- Nr.Uniques : 2
# Pave: 99.59%
# Grvl: 0.41%
#
#
# 3 Column: Alley --- Nr.Uniques : 3
# nan: 93.77%
# Grvl: 3.42%
# Pave: 2.81%
#
#
# 4 Column: LotType --- Nr.Uniques : 5
# Corner: 18.01%
# Inside: 72.05%
# CulDSac: 6.44%
# FR2: 3.22%
# FR3: 0.27%
#
#
# 5 Column: BldgType --- Nr.Uniques : 5
# 1Fam: 83.56%
# Twnhs: 2.95%
# Duplex: 3.56%
# 2fmCon: 2.12%
# TwnhsE: 7.81%
#
#
# 6 Column: HouseStyle --- Nr.Uniques : 9
# 1Fam: 0.07%
# SFoyer: 2.53%
# 2Story: 30.48%
# 1Story: 49.66%
# 2.5Unf: 0.75%
# 2.5Fin: 0.55%
# 1.5Fin: 10.55%
# SLvl: 4.45%
# 1.5Unf: 0.96%
#
#
# 10 Column: Foundation --- Nr.Uniques : 7
# CBlock: 40.07%
# PConc: 42.12%
# Slab: 1.58%
# BrkTil: 9.86%
# Do Not use this Field in the Model: 5.75%
# Stone: 0.41%
# Wood: 0.21%
#
#
# 12 Column: CentralAir --- Nr.Uniques : 2
# Y: 93.49%
# N: 6.51%
#
#
# 15 Column: GarageType --- Nr.Uniques : 7
# BuiltIn: 6.03%
# Attchd: 59.59%
# Detchd: 26.51%
# nan: 5.55%
# Basment: 1.30%
# 2Types: 0.41%
# CarPort: 0.62%
#
#
# 19 Column: SaleType --- Nr.Uniques : 9
# WD: 86.78%
# COD: 2.95%
# New: 8.36%
# CWD: 0.27%
# ConLI: 0.34%
# ConLD: 0.62%
# ConLw: 0.34%
# Con: 0.14%
# Oth: 0.21%
#
#
# 20 Column: SaleCondition --- Nr.Uniques : 7
# Normal: 69.66%
# AdjLand: 0.27%
# Abnorml: 6.92%
# Partial: 8.56%
# Family: 1.37%
# Alloca: 0.82%
# normal: 12.40%
