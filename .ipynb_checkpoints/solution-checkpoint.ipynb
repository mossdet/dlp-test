# %% [markdown]
# <img style="float: right;" src="img/openhouse_logo.png" width="200" height="200"/><br>
#
# # <center> <ins> House Price Prediction Coding Test <br><br> Linear-Regression <ins> </center>
# ### <center>by: Daniel Lachner-Piza, PhD <br> for: OpenHouse.ai </center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import etl.data_loader as dl
import eda.eda_engine as eda

# %% [markdown]
# # 1.Data Loading <a class="data-loading"></a>

# %%
# Import the dataset using the DataLoader class, which wraps several file types into one single data reader.
data_loader = dl.DataLoader("data/dataset.csv")
raw_df = data_loader.load_data()

# %% [markdown]
# # 2. Raw Data Exploration

# %%
eda_engine = eda.EDA_Engine(raw_df)
eda_engine.overview()
eda_engine.numerical_values()
eda_engine.categorical_values()
# Out:
# Dataset Shape: (1460, 22)
#
#
# Data Types:
# LotArea               int64
# GrLivArea             int64
# Street               object
# Alley                object
# LotType              object
# BldgType             object
# HouseStyle           object
# OverallQuality        int64
# OverallCondition      int64
# YearBuilt             int64
# Foundation           object
# TotalBsmtSF           int64
# CentralAir           object
# FullBath              int64
# HalfBath              int64
# GarageType           object
# GarageCars            int64
# GarageArea          float64
# YearSold              int64
# SaleType             object
# SaleCondition        object
# SalePrice             int64
# dtype: object
#
#
# First few rows:
#    LotArea  GrLivArea Street Alley  LotType BldgType HouseStyle  \
# 0     8910       1194   Pave   NaN   Corner     1Fam       1Fam
# 1     1526        630   Pave   NaN   Inside    Twnhs     SFoyer
# 2    14598       1933   Pave   NaN  CulDSac     1Fam     2Story
# 3     7200       1040   Pave   NaN   Inside   Duplex     1Story
# 4     5687       1716   Pave  Grvl   Inside   2fmCon     2Story
# 5     8100       1559   Pave  Pave   Inside     1Fam     1Story
# 6     9600       1644   Pave   NaN   Inside     1Fam     1Story
# 7     3182       1200   Pave  Pave   Inside   TwnhsE     2Story
# 8     6040       1152   Pave   NaN   Inside   Duplex     1Story
# 9    20544       2093   Pave   NaN  CulDSac     1Fam     2Story
#
#    OverallQuality  OverallCondition  YearBuilt  ... CentralAir  FullBath  \
# 0               6                 6       1959  ...          Y         1
# 1               4                 8       1970  ...          Y         1
# 2               6                 5       2007  ...          Y         2
# 3               4                 5       1949  ...          N         2
# 4               5                 6       1912  ...          N         2
# 5               5                 6       1948  ...          Y         1
# 6               6                 5       1953  ...          Y         1
# 7               7                 5       2004  ...          Y         2
# 8               4                 5       1955  ...          N         2
# 9               7                 6       1986  ...          Y         2
#
#   HalfBath  GarageType  GarageCars GarageArea  YearSold  SaleType  \
# 0        0     BuiltIn           2      539.0      2006        WD
# 1        0      Attchd           1      286.0      2009        WD
# 2        1     BuiltIn           3      668.0      2008        WD
# 3        0      Detchd           2      420.0      2009        WD
# 4        0         NaN           0        0.0      2008        WD
# 5        0      Detchd           2      812.0      2007       COD
# 6        0      Attchd           2      418.0      2009        WD
# 7        1      Detchd           2      480.0      2010        WD
# 8        0         NaN           0        0.0      2008        WD
# 9        1      Attchd           2      542.0      2008        WD
#
#    SaleCondition SalePrice
# 0         Normal    159500
# 1         Normal     86000
# 2         Normal    214000
# 3         Normal     90000
# 4         Normal    135900
# 5         Normal    153500
# 6         Normal    167000
# 7         Normal    151000
# 8        AdjLand     82000
# 9         Normal    215000
#
# [10 rows x 22 columns]
#
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   GrLivArea         1460 non-null   int64
#  2   Street            1460 non-null   object
#  3   Alley             91 non-null     object
#  4   LotType           1460 non-null   object
#  5   BldgType          1460 non-null   object
#  6   HouseStyle        1460 non-null   object
#  7   OverallQuality    1460 non-null   int64
#  8   OverallCondition  1460 non-null   int64
#  9   YearBuilt         1460 non-null   int64
#  10  Foundation        1460 non-null   object
#  11  TotalBsmtSF       1460 non-null   int64
#  12  CentralAir        1460 non-null   object
#  13  FullBath          1460 non-null   int64
#  14  HalfBath          1460 non-null   int64
#  15  GarageType        1379 non-null   object
#  16  GarageCars        1460 non-null   int64
#  17  GarageArea        1417 non-null   float64
#  18  YearSold          1460 non-null   int64
#  19  SaleType          1460 non-null   object
#  20  SaleCondition     1460 non-null   object
#  21  SalePrice         1460 non-null   int64
# dtypes: float64(1), int64(11), object(10)
# memory usage: 251.1+ KB
# None
#
#
# DataFrame columns:
# Index(['LotArea', 'GrLivArea', 'Street', 'Alley', 'LotType', 'BldgType',
#        'HouseStyle', 'OverallQuality', 'OverallCondition', 'YearBuilt',
#        'Foundation', 'TotalBsmtSF', 'CentralAir', 'FullBath', 'HalfBath',
#        'GarageType', 'GarageCars', 'GarageArea', 'YearSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')
#
#
# DataFrame index:
# RangeIndex(start=0, stop=1460, step=1)
#
#
# DataFrame nr. unique values:
# LotArea             1073
# GrLivArea            863
# Street                 2
# Alley                  2
# LotType                5
# BldgType               5
# HouseStyle             9
# OverallQuality        10
# OverallCondition       9
# YearBuilt            112
# Foundation             7
# TotalBsmtSF          721
# CentralAir             2
# FullBath               4
# HalfBath               3
# GarageType             6
# GarageCars             5
# GarageArea           435
# YearSold               5
# SaleType               9
# SaleCondition          7
# SalePrice            663
# dtype: int64
#
#
# DataFrame nr. missing values:
# LotArea                0
# GrLivArea              0
# Street                 0
# Alley               1369
# LotType                0
# BldgType               0
# HouseStyle             0
# OverallQuality         0
# OverallCondition       0
# YearBuilt              0
# Foundation             0
# TotalBsmtSF            0
# CentralAir             0
# FullBath               0
# HalfBath               0
# GarageType            81
# GarageCars             0
# GarageArea            43
# YearSold               0
# SaleType               0
# SaleCondition          0
# SalePrice              0
# dtype: int64
#
#
# DataFrame missing values percentage:
# LotArea              0.000000
# GrLivArea            0.000000
# Street               0.000000
# Alley               93.767123
# LotType              0.000000
# BldgType             0.000000
# HouseStyle           0.000000
# OverallQuality       0.000000
# OverallCondition     0.000000
# YearBuilt            0.000000
# Foundation           0.000000
# TotalBsmtSF          0.000000
# CentralAir           0.000000
# FullBath             0.000000
# HalfBath             0.000000
# GarageType           5.547945
# GarageCars           0.000000
# GarageArea           2.945205
# YearSold             0.000000
# SaleType             0.000000
# SaleCondition        0.000000
# SalePrice            0.000000
# dtype: float64
#
#
# Numerical values (Summarizing Stats %):
#
# 0 Column: LotArea --- Nr.Uniques: 1073 --- Min.: 1300.00 --- Max.: 215245.00 --- Mean: 10516.83 --- Median: 9478.50 --- StdDev: 9981.26
# 1 Column: GrLivArea --- Nr.Uniques: 863 --- Min.: 334.00 --- Max.: 23400.00 --- Mean: 1567.21 --- Median: 1466.00 --- StdDev: 1072.20
# 7 Column: OverallQuality --- Nr.Uniques: 10 --- Min.: 1.00 --- Max.: 10.00 --- Mean: 6.10 --- Median: 6.00 --- StdDev: 1.38
# 8 Column: OverallCondition --- Nr.Uniques: 9 --- Min.: 1.00 --- Max.: 9.00 --- Mean: 5.58 --- Median: 5.00 --- StdDev: 1.11
# 9 Column: YearBuilt --- Nr.Uniques: 112 --- Min.: 1872.00 --- Max.: 2010.00 --- Mean: 1971.27 --- Median: 1973.00 --- StdDev: 30.20
# 11 Column: TotalBsmtSF --- Nr.Uniques: 721 --- Min.: 0.00 --- Max.: 6110.00 --- Mean: 1057.43 --- Median: 991.50 --- StdDev: 438.71
# 13 Column: FullBath --- Nr.Uniques: 4 --- Min.: 0.00 --- Max.: 3.00 --- Mean: 1.57 --- Median: 2.00 --- StdDev: 0.55
# 14 Column: HalfBath --- Nr.Uniques: 3 --- Min.: 0.00 --- Max.: 2.00 --- Mean: 0.38 --- Median: 0.00 --- StdDev: 0.50
# 16 Column: GarageCars --- Nr.Uniques: 5 --- Min.: 0.00 --- Max.: 4.00 --- Mean: 1.77 --- Median: 2.00 --- StdDev: 0.75
# 17 Column: GarageArea --- Nr.Uniques: 436 --- Min.: 0.00 --- Max.: 1418.00 --- Mean: 471.41 --- Median: 478.00 --- StdDev: 214.22
# 18 Column: YearSold --- Nr.Uniques: 5 --- Min.: 2006.00 --- Max.: 2010.00 --- Mean: 2007.82 --- Median: 2008.00 --- StdDev: 1.33
# 21 Column: SalePrice --- Nr.Uniques: 663 --- Min.: 34900.00 --- Max.: 755000.00 --- Mean: 180921.20 --- Median: 163000.00 --- StdDev: 79442.50
#
#
# Categorical values (Unique entrees %):
#
# Column: Street --- Nr.Uniques : 2
# Pave: 99.59%
# Grvl: 0.41%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: Alley --- Nr.Uniques : 3
# nan: 93.77%
# Grvl: 3.42%
# Pave: 2.81%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: LotType --- Nr.Uniques : 5
# Corner: 18.01%
# Inside: 72.05%
# CulDSac: 6.44%
# FR2: 3.22%
# FR3: 0.27%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: BldgType --- Nr.Uniques : 5
# 1Fam: 83.56%
# Twnhs: 2.95%
# Duplex: 3.56%
# 2fmCon: 2.12%
# TwnhsE: 7.81%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: HouseStyle --- Nr.Uniques : 9
# 1Fam: 0.07%
# SFoyer: 2.53%
# 2Story: 30.48%
# 1Story: 49.66%
# 2.5Unf: 0.75%
# 2.5Fin: 0.55%
# 1.5Fin: 10.55%
# SLvl: 4.45%
# 1.5Unf: 0.96%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: Foundation --- Nr.Uniques : 7
# CBlock: 40.07%
# PConc: 42.12%
# Slab: 1.58%
# BrkTil: 9.86%
# Do Not use this Field in the Model: 5.75%
# Stone: 0.41%
# Wood: 0.21%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: CentralAir --- Nr.Uniques : 2
# Y: 93.49%
# N: 6.51%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: GarageType --- Nr.Uniques : 7
# BuiltIn: 6.03%
# Attchd: 59.59%
# Detchd: 26.51%
# nan: 5.55%
# Basment: 1.30%
# 2Types: 0.41%
# CarPort: 0.62%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleType --- Nr.Uniques : 9
# WD: 86.78%
# COD: 2.95%
# New: 8.36%
# CWD: 0.27%
# ConLI: 0.34%
# ConLD: 0.62%
# ConLw: 0.34%
# Con: 0.14%
# Oth: 0.21%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleCondition --- Nr.Uniques : 7
# Normal: 69.66%
# AdjLand: 0.27%
# Abnorml: 6.92%
# Partial: 8.56%
# Family: 1.37%
# Alloca: 0.82%
# normal: 12.40%
#
#
# Categorical Columns:Index(['Street', 'Alley', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # 3.Data Cleaning

# %% [markdown]
# ### <ins> 3.1. Handle NaNs <ins>

# %% [markdown]
# #### Drop column "Alley" because 94% of its entries are NaN

# %%
clean_df = raw_df.drop(["Alley"], axis='columns').copy()

# %% [markdown]
# #### Drop rows where any column ( in this case "GarageType" and "GarageArea") contains NaNs

# %%
clean_df = clean_df.dropna(axis='index', how='any')

# %%
print(f"Nr. Dropped Rows: {raw_df.shape[0]-clean_df.shape[0]} ({100*(1-(clean_df.shape[0]/raw_df.shape[0])):.2f}%)")
# Out:
# Nr. Dropped Rows: 124 (8.49%)

# %% [markdown]
# #### Check again for NaNs and duplicate rows

# %%
eda_engine = eda.EDA_Engine(clean_df)
eda_engine.missing_values()
eda_engine.duplicates()
# Out:
# 0 Column: LotArea --- Missing values: 0 --- Percentage: 0.00%
# 1 Column: GrLivArea --- Missing values: 0 --- Percentage: 0.00%
# 2 Column: Street --- Missing values: 0 --- Percentage: 0.00%
# 3 Column: LotType --- Missing values: 0 --- Percentage: 0.00%
# 4 Column: BldgType --- Missing values: 0 --- Percentage: 0.00%
# 5 Column: HouseStyle --- Missing values: 0 --- Percentage: 0.00%
# 6 Column: OverallQuality --- Missing values: 0 --- Percentage: 0.00%
# 7 Column: OverallCondition --- Missing values: 0 --- Percentage: 0.00%
# 8 Column: YearBuilt --- Missing values: 0 --- Percentage: 0.00%
# 9 Column: Foundation --- Missing values: 0 --- Percentage: 0.00%
# 10 Column: TotalBsmtSF --- Missing values: 0 --- Percentage: 0.00%
# 11 Column: CentralAir --- Missing values: 0 --- Percentage: 0.00%
# 12 Column: FullBath --- Missing values: 0 --- Percentage: 0.00%
# 13 Column: HalfBath --- Missing values: 0 --- Percentage: 0.00%
# 14 Column: GarageType --- Missing values: 0 --- Percentage: 0.00%
# 15 Column: GarageCars --- Missing values: 0 --- Percentage: 0.00%
# 16 Column: GarageArea --- Missing values: 0 --- Percentage: 0.00%
# 17 Column: YearSold --- Missing values: 0 --- Percentage: 0.00%
# 18 Column: SaleType --- Missing values: 0 --- Percentage: 0.00%
# 19 Column: SaleCondition --- Missing values: 0 --- Percentage: 0.00%
# 20 Column: SalePrice --- Missing values: 0 --- Percentage: 0.00%
# Number of duplicate rows: 0

# %% [markdown]
# ### <ins> 3.2 Clean categorical values <ins>
# - Clean entries with the value "Do Not use this Field in the Model". Assign them a shorter value
# - Clean entries that are the same but written with a different case (e.g. "Normal" and "normal")

# %%
print("Before cleaning")
eda_engine.categorical_values()
# Out:
# Before cleaning
# Categorical values (Unique entrees %):
#
# Column: Street --- Nr.Uniques : 2
# Pave: 99.63%
# Grvl: 0.37%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: LotType --- Nr.Uniques : 5
# Corner: 18.04%
# Inside: 71.71%
# CulDSac: 6.74%
# FR2: 3.22%
# FR3: 0.30%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: BldgType --- Nr.Uniques : 5
# 1Fam: 84.51%
# Twnhs: 2.69%
# Duplex: 2.99%
# TwnhsE: 8.23%
# 2fmCon: 1.57%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: HouseStyle --- Nr.Uniques : 9
# 1Fam: 0.07%
# SFoyer: 2.32%
# 2Story: 31.14%
# 1Story: 49.93%
# 2.5Unf: 0.75%
# 2.5Fin: 0.37%
# 1.5Fin: 10.25%
# SLvl: 4.64%
# 1.5Unf: 0.52%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: Foundation --- Nr.Uniques : 7
# CBlock: 39.22%
# PConc: 43.56%
# Slab: 1.42%
# BrkTil: 9.21%
# Do Not use this Field in the Model: 5.91%
# Stone: 0.45%
# Wood: 0.22%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: CentralAir --- Nr.Uniques : 2
# Y: 94.99%
# N: 5.01%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: GarageType --- Nr.Uniques : 6
# BuiltIn: 6.21%
# Attchd: 63.17%
# Detchd: 28.07%
# Basment: 1.42%
# 2Types: 0.45%
# CarPort: 0.67%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleType --- Nr.Uniques : 9
# WD: 86.90%
# COD: 3.14%
# New: 8.46%
# CWD: 0.30%
# ConLI: 0.22%
# ConLD: 0.52%
# Con: 0.07%
# ConLw: 0.30%
# Oth: 0.07%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleCondition --- Nr.Uniques : 7
# Normal: 71.11%
# Abnorml: 6.21%
# Partial: 8.68%
# Family: 1.50%
# Alloca: 0.82%
# AdjLand: 0.07%
# normal: 11.60%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
col_name = 'Foundation'
unique_val = "Do Not use this Field in the Model"
clean_df.loc[clean_df[col_name].str.fullmatch(unique_val, case=True), col_name] = 'Unknown'

# %%
col_name = 'SaleCondition'
unique_val = "normal"
clean_df.loc[clean_df[col_name].str.fullmatch(unique_val, case=True), col_name] = 'Normal'

# %%
print("After cleaning")
eda_engine = eda.EDA_Engine(clean_df)
eda_engine.categorical_values()
eda_engine.numerical_values()
# Out:
# After cleaning
# Categorical values (Unique entrees %):
#
# Column: Street --- Nr.Uniques : 2
# Pave: 99.63%
# Grvl: 0.37%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: LotType --- Nr.Uniques : 5
# Corner: 18.04%
# Inside: 71.71%
# CulDSac: 6.74%
# FR2: 3.22%
# FR3: 0.30%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: BldgType --- Nr.Uniques : 5
# 1Fam: 84.51%
# Twnhs: 2.69%
# Duplex: 2.99%
# TwnhsE: 8.23%
# 2fmCon: 1.57%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: HouseStyle --- Nr.Uniques : 9
# 1Fam: 0.07%
# SFoyer: 2.32%
# 2Story: 31.14%
# 1Story: 49.93%
# 2.5Unf: 0.75%
# 2.5Fin: 0.37%
# 1.5Fin: 10.25%
# SLvl: 4.64%
# 1.5Unf: 0.52%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: Foundation --- Nr.Uniques : 7
# CBlock: 39.22%
# PConc: 43.56%
# Slab: 1.42%
# BrkTil: 9.21%
# Unknown: 5.91%
# Stone: 0.45%
# Wood: 0.22%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: CentralAir --- Nr.Uniques : 2
# Y: 94.99%
# N: 5.01%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: GarageType --- Nr.Uniques : 6
# BuiltIn: 6.21%
# Attchd: 63.17%
# Detchd: 28.07%
# Basment: 1.42%
# 2Types: 0.45%
# CarPort: 0.67%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleType --- Nr.Uniques : 9
# WD: 86.90%
# COD: 3.14%
# New: 8.46%
# CWD: 0.30%
# ConLI: 0.22%
# ConLD: 0.52%
# Con: 0.07%
# ConLw: 0.30%
# Oth: 0.07%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleCondition --- Nr.Uniques : 6
# Normal: 82.71%
# Abnorml: 6.21%
# Partial: 8.68%
# Family: 1.50%
# Alloca: 0.82%
# AdjLand: 0.07%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Numerical values (Summarizing Stats %):
#
# 0 Column: LotArea --- Nr.Uniques: 992 --- Min.: 1300.00 --- Max.: 215245.00 --- Mean: 10720.67 --- Median: 9579.50 --- StdDev: 10351.69
# 1 Column: GrLivArea --- Nr.Uniques: 815 --- Min.: 438.00 --- Max.: 23400.00 --- Mean: 1587.73 --- Median: 1480.00 --- StdDev: 1103.06
# 6 Column: OverallQuality --- Nr.Uniques: 9 --- Min.: 2.00 --- Max.: 10.00 --- Mean: 6.17 --- Median: 6.00 --- StdDev: 1.34
# 7 Column: OverallCondition --- Nr.Uniques: 8 --- Min.: 2.00 --- Max.: 9.00 --- Mean: 5.58 --- Median: 5.00 --- StdDev: 1.09
# 8 Column: YearBuilt --- Nr.Uniques: 109 --- Min.: 1880.00 --- Max.: 2010.00 --- Mean: 1972.83 --- Median: 1976.00 --- StdDev: 29.46
# 10 Column: TotalBsmtSF --- Nr.Uniques: 695 --- Min.: 0.00 --- Max.: 6110.00 --- Mean: 1073.50 --- Median: 1008.00 --- StdDev: 438.59
# 12 Column: FullBath --- Nr.Uniques: 4 --- Min.: 0.00 --- Max.: 3.00 --- Mean: 1.58 --- Median: 2.00 --- StdDev: 0.55
# 13 Column: HalfBath --- Nr.Uniques: 3 --- Min.: 0.00 --- Max.: 2.00 --- Mean: 0.39 --- Median: 0.00 --- StdDev: 0.50
# 15 Column: GarageCars --- Nr.Uniques: 4 --- Min.: 1.00 --- Max.: 4.00 --- Mean: 1.87 --- Median: 2.00 --- StdDev: 0.63
# 16 Column: GarageArea --- Nr.Uniques: 434 --- Min.: 160.00 --- Max.: 1418.00 --- Mean: 499.99 --- Median: 484.00 --- StdDev: 185.40
# 17 Column: YearSold --- Nr.Uniques: 5 --- Min.: 2006.00 --- Max.: 2010.00 --- Mean: 2007.81 --- Median: 2008.00 --- StdDev: 1.34
# 20 Column: SalePrice --- Nr.Uniques: 624 --- Min.: 35311.00 --- Max.: 755000.00 --- Mean: 184803.62 --- Median: 167500.00 --- StdDev: 78573.41

# %% [markdown]
# ### <ins> 3.3. Explore the dataset and categorize each feature as numerical, categorical or ordinal<ins>

# %%
contin_num_cols = ['LotArea', 'GrLivArea', 'YearBuilt', 'TotalBsmtSF', 'GarageArea']
ordinal_cols = ['OverallQuality','OverallCondition','FullBath','HalfBath','GarageCars','YearSold']
categorical_columns = ['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation', 'CentralAir', 'GarageType', 'SaleType', 'SaleCondition']
print(f"Numerical Columns: {contin_num_cols}")
print(f"Ordinal Columns: {ordinal_cols}")
print(f"Categorical Columns: {categorical_columns}")
# Out:
# Numerical Columns: ['LotArea', 'GrLivArea', 'YearBuilt', 'TotalBsmtSF', 'GarageArea']
# Ordinal Columns: ['OverallQuality', 'OverallCondition', 'FullBath', 'HalfBath', 'GarageCars', 'YearSold']
# Categorical Columns: ['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation', 'CentralAir', 'GarageType', 'SaleType', 'SaleCondition']

# %%
df_numerical = clean_df[contin_num_cols].copy()
df_ordinal = clean_df[ordinal_cols].copy()
df_categorical = clean_df[categorical_columns].copy()
y_df = clean_df['SalePrice'].copy()

# %%
print("Numerical Features")
eda_engine = eda.EDA_Engine(df_numerical)
eda_engine.categorical_values()
eda_engine.numerical_values()
# Out:
# Numerical Features
# Categorical values (Unique entrees %):
#
# Numerical values (Summarizing Stats %):
#
# 0 Column: LotArea --- Nr.Uniques: 992 --- Min.: 1300.00 --- Max.: 215245.00 --- Mean: 10720.67 --- Median: 9579.50 --- StdDev: 10351.69
# 1 Column: GrLivArea --- Nr.Uniques: 815 --- Min.: 438.00 --- Max.: 23400.00 --- Mean: 1587.73 --- Median: 1480.00 --- StdDev: 1103.06
# 2 Column: YearBuilt --- Nr.Uniques: 109 --- Min.: 1880.00 --- Max.: 2010.00 --- Mean: 1972.83 --- Median: 1976.00 --- StdDev: 29.46
# 3 Column: TotalBsmtSF --- Nr.Uniques: 695 --- Min.: 0.00 --- Max.: 6110.00 --- Mean: 1073.50 --- Median: 1008.00 --- StdDev: 438.59
# 4 Column: GarageArea --- Nr.Uniques: 434 --- Min.: 160.00 --- Max.: 1418.00 --- Mean: 499.99 --- Median: 484.00 --- StdDev: 185.40

# %%
print("Ordinal Features")
eda_engine = eda.EDA_Engine(df_ordinal)
eda_engine.categorical_values()
eda_engine.numerical_values()
# Out:
# Ordinal Features
# Categorical values (Unique entrees %):
#
# Numerical values (Summarizing Stats %):
#
# 0 Column: OverallQuality --- Nr.Uniques: 9 --- Min.: 2.00 --- Max.: 10.00 --- Mean: 6.17 --- Median: 6.00 --- StdDev: 1.34
# 1 Column: OverallCondition --- Nr.Uniques: 8 --- Min.: 2.00 --- Max.: 9.00 --- Mean: 5.58 --- Median: 5.00 --- StdDev: 1.09
# 2 Column: FullBath --- Nr.Uniques: 4 --- Min.: 0.00 --- Max.: 3.00 --- Mean: 1.58 --- Median: 2.00 --- StdDev: 0.55
# 3 Column: HalfBath --- Nr.Uniques: 3 --- Min.: 0.00 --- Max.: 2.00 --- Mean: 0.39 --- Median: 0.00 --- StdDev: 0.50
# 4 Column: GarageCars --- Nr.Uniques: 4 --- Min.: 1.00 --- Max.: 4.00 --- Mean: 1.87 --- Median: 2.00 --- StdDev: 0.63
# 5 Column: YearSold --- Nr.Uniques: 5 --- Min.: 2006.00 --- Max.: 2010.00 --- Mean: 2007.81 --- Median: 2008.00 --- StdDev: 1.34

# %%
print("Categorical Features")
eda_engine = eda.EDA_Engine(df_categorical)
eda_engine.categorical_values()
eda_engine.numerical_values()
# Out:
# Categorical Features
# Categorical values (Unique entrees %):
#
# Column: Street --- Nr.Uniques : 2
# Pave: 99.63%
# Grvl: 0.37%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: LotType --- Nr.Uniques : 5
# Corner: 18.04%
# Inside: 71.71%
# CulDSac: 6.74%
# FR2: 3.22%
# FR3: 0.30%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: BldgType --- Nr.Uniques : 5
# 1Fam: 84.51%
# Twnhs: 2.69%
# Duplex: 2.99%
# TwnhsE: 8.23%
# 2fmCon: 1.57%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: HouseStyle --- Nr.Uniques : 9
# 1Fam: 0.07%
# SFoyer: 2.32%
# 2Story: 31.14%
# 1Story: 49.93%
# 2.5Unf: 0.75%
# 2.5Fin: 0.37%
# 1.5Fin: 10.25%
# SLvl: 4.64%
# 1.5Unf: 0.52%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: Foundation --- Nr.Uniques : 7
# CBlock: 39.22%
# PConc: 43.56%
# Slab: 1.42%
# BrkTil: 9.21%
# Unknown: 5.91%
# Stone: 0.45%
# Wood: 0.22%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: CentralAir --- Nr.Uniques : 2
# Y: 94.99%
# N: 5.01%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: GarageType --- Nr.Uniques : 6
# BuiltIn: 6.21%
# Attchd: 63.17%
# Detchd: 28.07%
# Basment: 1.42%
# 2Types: 0.45%
# CarPort: 0.67%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleType --- Nr.Uniques : 9
# WD: 86.90%
# COD: 3.14%
# New: 8.46%
# CWD: 0.30%
# ConLI: 0.22%
# ConLD: 0.52%
# Con: 0.07%
# ConLw: 0.30%
# Oth: 0.07%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Column: SaleCondition --- Nr.Uniques : 6
# Normal: 82.71%
# Abnorml: 6.21%
# Partial: 8.68%
# Family: 1.50%
# Alloca: 0.82%
# AdjLand: 0.07%
#
#
# Categorical Columns:Index(['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation',
#        'CentralAir', 'GarageType', 'SaleType', 'SaleCondition'],
#       dtype='object')
#
# Numerical values (Summarizing Stats %):

# %% [markdown]
# ### <ins> Inspect each feature and its relationship with the target

# %%
df_numerical
df_ordinal
df_categorical
y_df

contin_num_cols = ['LotArea', 'GrLivArea', 'YearBuilt', 'TotalBsmtSF', 'GarageArea']
ordinal_cols = ['OverallQuality','OverallCondition','FullBath','HalfBath','GarageCars','YearSold']
categorical_columns = ['Street', 'LotType', 'BldgType', 'HouseStyle', 'Foundation', 'CentralAir', 'GarageType', 'SaleType', 'SaleCondition']

# %% [markdown]
# # Continous Numerical Features

# %%
df = df_numerical.copy()
df['price'] = y_df.to_numpy()
for feat_name in contin_num_cols:
    fig = plt.figure(figsize = (5,10))
    ax = fig.subplots()
    sns.boxplot(data=df, x=feat_name,y='price', hue=feat_name, ax=ax);
    plt.xticks(rotation=90);

# %% [markdown]
# # Ordinal Features

# %%
df = df_ordinal.copy()
df['price'] = y_df.to_numpy()
for feat_name in ordinal_cols:
    fig = plt.figure(figsize = (5,10))
    ax = fig.subplots()
    sns.boxplot(data=df, x=feat_name,y='price', hue=feat_name, ax=ax);
    plt.xticks(rotation=90);

# %% [markdown]
# # Categorical Features

# %%
df = df_categorical.copy()
df['price'] = y_df.to_numpy()
for feat_name in categorical_columns:
    fig = plt.figure(figsize = (5,10))
    ax = fig.subplots()
    sns.boxplot(data=df, x=feat_name,y='price', hue=feat_name, ax=ax);
    plt.xticks(rotation=90);
